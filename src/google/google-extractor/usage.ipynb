# %% [markdown]
# ### Extract login and access data for students in Google Classroom

# %%
from main import request
df = request().usage()
# Out:
# INFO:root:Pulling usage data

# %%
df.shape
# Out:
# (231, 9)

# %%
df.head()
# Out:
#                              email   asOfDate importDate  numberOfPosts  \
# 0          admin@ibamonitoring.org 2020-08-19 2020-09-02              1
# 1  kelley.christian@studentgps.org 2020-08-19 2020-09-02              2
# 2       kyle.hughes@studentgps.org 2020-08-19 2020-09-02              0
# 3     larry.mahoney@studentgps.org 2020-08-19 2020-09-02              0
# 4       mary.archer@studentgps.org 2020-08-19 2020-09-02              1
#
#   lastInteractionTime       lastLoginTime              name monthDay  \
# 0 2020-08-19 21:16:55 2020-08-20 02:57:44             admin    08/19
# 1 2020-08-19 21:05:39 2020-08-19 20:24:35  kelley.christian    08/19
# 2 1970-01-01 00:00:00 2020-08-19 20:14:43       kyle.hughes    08/19
# 3 1970-01-01 00:00:00 2020-08-19 20:19:20     larry.mahoney    08/19
# 4 2020-08-19 20:58:07 2020-08-19 20:15:29       mary.archer    08/19
#
#                  nameDate
# 0             admin 08/19
# 1  kelley.christian 08/19
# 2       kyle.hughes 08/19
# 3     larry.mahoney 08/19
# 4       mary.archer 08/19

# %% [markdown]
# ### For each user/date pair, how many posts?

# %%
ax = df.plot(x="nameDate", y="numberOfPosts", kind="bar", title="Posts", figsize=(20, 8))

# %% [markdown]
# ### Graph per user, how many posts on each date?

# %%
import matplotlib.pyplot as plt
import seaborn as sns

x = sns.FacetGrid(df, col="name", col_wrap=6)
ax = x.map(plt.bar, "monthDay", "numberOfPosts")

# %% [markdown]
# ### Graph per user, how many days for each number of posts?

# %%
x = sns.FacetGrid(df, col="name", col_wrap=6)
ax = x.map(plt.hist, "numberOfPosts")
